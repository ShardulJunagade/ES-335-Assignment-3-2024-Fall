# %%
import json
import torch

# Load vocabulary mappings (ensure one-time loading)
with open("assets/word_to_index.json", "r") as f:
    word_to_index = json.load(f)


with open("assets/index_to_word.json", "r") as f:
    index_to_word = json.load(f)
    index_to_word = {int(k): v for k, v in index_to_word.items()}


vocab_size = len(word_to_index)  # Make sure it matches training vocab size

# Set up device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F


# Define the improved MLP model
class ImprovedMLP(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, dropout_rate, context_size, activation_function):
        super(ImprovedMLP, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.fc1 = nn.Linear(embedding_dim * context_size, hidden_dim)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, vocab_size)
        self.activation_function = activation_function

    def forward(self, x):
        x = self.embedding(x).view(x.size(0), -1)
        x = self.dropout1(self.activation_function(self.bn1(self.fc1(x))))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)


embedding_dim = 32
hidden_dim = 1024
dropout_rate = 0.3
context_size = 5
activation_function = nn.LeakyReLU()
model = ImprovedMLP(vocab_size, embedding_dim,hidden_dim, dropout_rate, context_size, activation_function)

# Example loading for a PyTorch model
model_path = "models/model_context_5_emb_32_act_leaky_relu_seed_42.pth"
# Load the state dictionary
model.load_state_dict(torch.load(model_path, map_location=torch.device('cpu')))
model.eval()

# Extract embeddings
embedding_layer = model.embedding.weight.detach().cpu().numpy

# %%
# Extract embeddings as a PyTorch tensor
embedding_layer = model.embedding.weight.detach().cpu()

# Confirm the type and view the shape
print("Type of embedding_layer:", type(embedding_layer))
print("Shape of embedding_layer:", embedding_layer.shape)
print("First few entries of the embedding layer:", embedding_layer[:5])
# Out:
# Type of embedding_layer: <class 'torch.Tensor'>
# Shape of embedding_layer: torch.Size([14343, 32])
# First few entries of the embedding layer: tensor([[ 0.1607, -0.8831,  0.9053,  0.3046,  1.1314, -0.0213,  0.0537, -1.3349,
#          -0.3744,  1.6580, -0.4364,  0.9736, -0.0852, -1.8226,  0.0389,  0.8106,
#           1.3936, -1.3252, -0.4490, -0.1550, -0.0816,  1.4668,  0.7676,  0.6426,
#           0.9667,  2.3175, -1.0444, -0.4604, -1.4124,  0.2381,  0.3254,  0.7909],
#         [-1.9379,  1.2617,  1.4001,  0.5934, -1.6363,  0.1354,  0.5916,  3.0951,
#           2.2618,  0.7057,  0.2028, -1.7554,  0.9461,  0.0473, -0.2410, -0.4252,
#          -0.4355,  0.5923,  2.8197,  0.5316, -1.4165,  1.7443, -1.1300,  1.0919,
#           0.1573, -0.7654, -0.7492,  2.1439,  0.8276, -0.5683, -1.9366, -1.9796],
#         [ 1.4292, -0.9563,  2.4447, -0.4073, -1.9755, -2.1960, -1.1864,  0.7653,
#          -0.7518, -1.6341, -1.0671,  1.1376,  1.8026, -0.4890, -4.2620, -1.3836,
#          -0.9479,  1.3315,  1.4379,  1.1982,  1.5349,  0.8557,  0.8223,  0.3849,
#           1.9686, -0.2439, -0.5391,  0.8581, -0.5177, -3.1850, -0.6516,  1.9101],
#         [-2.3430, -1.4377,  1.1965, -0.7242,  1.1618,  2.0271, -0.0603, -0.5473,
#          -0.9134, -0.8203,  0.6528, -2.1674,  0.4102,  1.9953, -1.0784,  2.1516,
#          -0.8763, -1.0810, -2.5855,  0.1913, -1.4277, -0.0306, -0.1209, -2.4279,
#           0.1347,  0.6247, -1.7854,  1.4424,  1.1027,  0.1719,  0.1242, -0.7043],
#         [ 1.8997,  0.5312,  0.9159, -0.1370,  0.0109,  1.5423,  0.2447,  1.6647,
#           0.4842,  0.0686, -3.4552,  1.9999, -1.1208,  0.2151, -2.1486,  1.5380,
#           0.2300,  0.5339,  0.0344,  0.5021,  0.1964,  1.5379, -0.9970, -0.4583,
#          -0.8515,  1.5657,  1.5882,  0.8991, -0.3464,  0.2555, -4.1399,  2.3492]])

# %%
print(len(word_to_index))
# Out:
# 14343

# %% [markdown]
# ### Visualization

# %%
from sklearn.manifold import TSNE
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import numpy as np

# Reduce embedding dimensionality
tsne = TSNE(n_components=2, random_state=42)
reduced_embeddings = tsne.fit_transform(embedding_layer.cpu())

# Words to annotate and analyze
words_to_annotate = ["bake", "cake", "chicken", "meat", "rice", "milk", "cream", "fry", "oven", "masala", "pastry", "and", "add", "mix", "chopped", "onions"]
indices = [word_to_index[word] for word in words_to_annotate]
annotated_embeddings = reduced_embeddings[indices]

# Compute pairwise distances
distances = pairwise_distances(annotated_embeddings)

# Find closest and furthest pairs
closest_pair_indices = np.unravel_index(np.argmin(distances + np.eye(len(distances)) * distances.max()), distances.shape)
furthest_pair_indices = np.unravel_index(np.argmax(distances), distances.shape)

print("Closest words:", words_to_annotate[closest_pair_indices[0]], "and", words_to_annotate[closest_pair_indices[1]])
print("Furthest words:", words_to_annotate[furthest_pair_indices[0]], "and", words_to_annotate[furthest_pair_indices[1]])

# Plot embeddings
plt.figure(figsize=(10, 10))
plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1], alpha=0.5, s=1)
plt.title("2D t-SNE of Word Embeddings")

# Annotate specified words
for word in words_to_annotate:
    index = word_to_index[word]
    x, y = reduced_embeddings[index]
    plt.scatter(x, y, color='red', s=40)
    plt.annotate(word, (x, y), textcoords="offset points", xytext=(0, 10), ha='center', fontsize=8)

plt.show()
# Out:
# Closest words: chicken and meat
# Furthest words: fry and and

# %%
import plotly.express as px
import numpy as np
from sklearn.manifold import TSNE

# Reduce embedding dimensionality
tsne = TSNE(n_components=3, random_state=42)
reduced_embeddings = tsne.fit_transform(embedding_layer.cpu())

# Words to annotate and analyze
words_to_annotate = ["bake", "cake", "chicken", "meat", "rice", "milk", "cream", "fry", "oven", "masala", "pastry", "and", "add", "mix", "chopped", "onions"]
indices = [word_to_index[word] for word in words_to_annotate]
annotated_embeddings = reduced_embeddings[indices]

# Create a DataFrame for Plotly
import pandas as pd

df = pd.DataFrame(reduced_embeddings, columns=['x', 'y', 'z'])
df['word'] = ['Word ' + str(i) for i in range(len(reduced_embeddings))]
df.loc[indices, 'word'] = words_to_annotate  # Set actual words for annotated embeddings

# Create 3D scatter plot
fig = px.scatter_3d(df, x='x', y='y', z='z', text='word', title='3D t-SNE of Word Embeddings')

# Show plot
fig.update_traces(textposition='top center')
fig.show()

# %%
# !pip install torchviz
# Out:
# Collecting torchviz
#   Downloading torchviz-0.0.2.tar.gz (4.9 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: torch in c:\users\soham\anaconda3\envs\pytorch_env\lib\site-packages (from torchviz) (2.3.0)
# Collecting graphviz (from torchviz)
#   Using cached graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock in c:\users\soham\anaconda3\envs\pytorch_env\lib\site-packages (from torch->torchviz) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\soham\anaconda3\envs\pytorch_env\lib\site-packages (from torch->torchviz) (4.11.0)
# Requirement already satisfied: sympy in c:\users\soham\anaconda3\envs\pytorch_env\lib\site-packages (from torch->torchviz) (1.13.2)
# Requirement already satisfied: networkx in c:\users\soham\anaconda3\envs\pytorch_env\lib\site-packages (from torch->torchviz) (3.3)
# Requirement already satisfied: jinja2 in c:\users\soham\anaconda3\envs\pytorch_env\lib\site-packages (from torch->torchviz) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\soham\anaconda3\envs\pytorch_env\lib\site-packages (from torch->torchviz) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\soham\anaconda3\envs\pytorch_env\lib\site-packages (from torch->torchviz) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\soham\anaconda3\envs\pytorch_env\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->torchviz) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\soham\anaconda3\envs\pytorch_env\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->torchviz) (2021.13.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\soham\anaconda3\envs\pytorch_env\lib\site-packages (from jinja2->torch->torchviz) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\soham\anaconda3\envs\pytorch_env\lib\site-packages (from sympy->torch->torchviz) (1.3.0)
# Using cached graphviz-0.20.3-py3-none-any.whl (47 kB)
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py): started
#   Building wheel for torchviz (setup.py): finished with status 'done'
#   Created wheel for torchviz: filename=torchviz-0.0.2-py3-none-any.whl size=4137 sha256=e26d1ba1ebd4cfafb4e24ab4a3b9a0b18ccbf5ee1add1ae121ad768a0a625720
#   Stored in directory: c:\users\soham\appdata\local\pip\cache\wheels\98\f2\3d\290537e0ff7f67aaa647847a10fb5ee5eca305b3c41a774523
# Successfully built torchviz
# Installing collected packages: graphviz, torchviz
# Successfully installed graphviz-0.20.3 torchviz-0.0.2

# %%
import torch
from torchviz import make_dot

# Instantiate your model
vocab_size = 1000  # Example size
embedding_dim = 50
hidden_dim = 100
dropout_rate = 0.5
context_size = 3
activation_function = torch.nn.ReLU()

model = ImprovedMLP(vocab_size, embedding_dim, hidden_dim, dropout_rate, context_size, activation_function)

# Create a dummy input tensor with appropriate shape
dummy_input = torch.randint(0, vocab_size, (1, context_size))  # Batch size of 1

# Forward pass to create the computational graph
output = model(dummy_input)

# Visualize the model architecture
dot = make_dot(output, params=dict(model.named_parameters()))
dot.render("improved_mlp_architecture", format="png")  # Save as PNG
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 18
#      15 dummy_input = torch.randint(0, vocab_size, (1, context_size))  # Batch size of 1
#      17 # Forward pass to create the computational graph
# ---> 18 output = model(dummy_input)
#      20 # Visualize the model architecture
#      21 dot = make_dot(output, params=dict(model.named_parameters()))
#
# File c:\Users\Soham\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Soham\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[16], line 36, in ImprovedMLP.forward(self, x)
#      34 def forward(self, x):
#      35     x = self.embedding(x).view(x.size(0), -1)
# ---> 36     x = self.dropout1(self.activation_function(self.bn1(self.fc1(x))))
#      37     x = self.fc2(x)
#      38     return F.log_softmax(x, dim=1)
#
# File c:\Users\Soham\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Soham\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\Soham\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\batchnorm.py:175, in _BatchNorm.forward(self, input)
#     168     bn_training = (self.running_mean is None) and (self.running_var is None)
#     170 r"""
#     171 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     172 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     173 used for normalization (i.e. in eval mode when buffers are not None).
#     174 """
# --> 175 return F.batch_norm(
#     176     input,
#     177     # If buffers are not to be tracked, ensure that they won't be updated
#     178     self.running_mean
#     179     if not self.training or self.track_running_stats
#     180     else None,
#     181     self.running_var if not self.training or self.track_running_stats else None,
#     182     self.weight,
#     183     self.bias,
#     184     bn_training,
#     185     exponential_average_factor,
#     186     self.eps,
#     187 )
#
# File c:\Users\Soham\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\functional.py:2507, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2494     return handle_torch_function(
#    2495         batch_norm,
#    2496         (input, running_mean, running_var, weight, bias),
#    (...)
#    2504         eps=eps,
#    2505     )
#    2506 if training:
# -> 2507     _verify_batch_size(input.size())
#    2509 return torch.batch_norm(
#    2510     input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2511 )
#
# File c:\Users\Soham\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\functional.py:2475, in _verify_batch_size(size)
#    2473     size_prods *= size[i + 2]
#    2474 if size_prods == 1:
# -> 2475     raise ValueError(f"Expected more than 1 value per channel when training, got input size {size}")
#
# ValueError: Expected more than 1 value per channel when training, got input size torch.Size([1, 100])
